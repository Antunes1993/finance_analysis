# %%
import investpy

ticker = 'PETR4'
data = investpy.get_stock_historical_data(stock=ticker, country='brazil', from_date='01/01/2020', to_date='01/01/2023')
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[6], line 4
#       1 import investpy
#       3 ticker = 'PETR4'
# ----> 4 data = investpy.get_stock_historical_data(stock=ticker, country='brazil', from_date='01/01/2020', to_date='01/01/2023')
#       5 print(data.head())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\investpy\stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
# !pip install investpy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#       --------------------------------------- 0.1/4.4 MB 812.7 kB/s eta 0:00:06
#       --------------------------------------- 0.1/4.4 MB 812.7 kB/s eta 0:00:06
#      - -------------------------------------- 0.1/4.4 MB 1.1 MB/s eta 0:00:04
#      -- ------------------------------------- 0.3/4.4 MB 1.4 MB/s eta 0:00:03
#      --- ------------------------------------ 0.4/4.4 MB 1.6 MB/s eta 0:00:03
#      --- ------------------------------------ 0.4/4.4 MB 1.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 0.6/4.4 MB 1.9 MB/s eta 0:00:03
# ...
