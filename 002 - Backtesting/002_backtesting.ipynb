# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
from pandas_datareader import data as web
import yfinance as yf
import seaborn as sb
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from scipy.stats import norm

# %%
initial_amount = 10000 #Ten thousand BRL. 
tickers = ["TAEE3.SA"]
yf.pdr_override()
start_date = "2023-01-01"
end_date = datetime.today().strftime('%Y-%m-%d')
data = round(web.get_data_yahoo(tickers, start=start_date, end=end_date), 2)
short_window = 7
long_window = 90


data['SMA_Short'] = data['Close'].rolling(window=short_window).mean().round(2)
data['SMA_Long'] = data['Close'].rolling(window=long_window).mean().round(2)

data['EMA_Short'] = data['Close'].ewm(span=short_window).mean().round(2)
data['EMA_Long'] = data['Close'].ewm(span=long_window).mean().round(2)
data.dropna(inplace=True)
data.iloc[:, :8].head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#              Open   High    Low  Close  Adj Close  Volume  SMA_Short  SMA_Long
# Date
# 2023-05-12  12.31  12.46  12.00  12.36      11.15  155000      12.10     11.84
# 2023-05-15  12.33  12.45  12.30  12.34      11.13   67700      12.18     11.85
# 2023-05-16  12.35  12.45  12.28  12.34      11.13   74200      12.23     11.86
# 2023-05-17  12.30  12.44  12.28  12.33      11.12   75100      12.28     11.87
# 2023-05-18  12.33  12.49  12.28  12.37      11.16  115000      12.32     11.88

# %%
str_mode = "EMA"
str_short = "EMA_Short"
str_long = "EMA_Long"

# Lógica para os buy signals
buy_signals = (data[str_short] > data[str_long]) & (data[str_short].shift(1) <= data[str_long].shift(1))
sell_signals = (data[str_short] < data[str_long]) & (data[str_short].shift(1) >= data[str_long].shift(1))

# Criação da coluna 'Buy_Signal' com 1 para buy signal e 0 caso contrário
data['Buy_Signal'] = np.where(buy_signals, 1, 0)
data['Sell_Signal'] = np.where(sell_signals, -1, 0)

# %%
data['Recommend'] = 0
data.loc[data['Buy_Signal'] == 1, 'Recommend'] = 1
data.loc[data['Sell_Signal'] == -1, 'Recommend'] = -1
data = data.drop(['Buy_Signal', 'Sell_Signal'], axis=1)
data[['Recommend']].value_counts()
# Out:
# Recommend
#  0           293
# -1             4
#  1             3
# Name: count, dtype: int64

# %%
data.loc[data.index[2], 'Recommend'] = 1
data.loc[data.index[8], 'Recommend'] = -1
data.loc[data.index[12], 'Recommend'] = 1
data.loc[data.index[15], 'Recommend'] = -1

data['Profit'] = 0
data = data.head(20)
data
# Out:
#              Open   High    Low  Close  Adj Close  Volume  SMA_Short  \
# Date
# 2023-05-12  12.31  12.46  12.00  12.36      11.15  155000      12.10
# 2023-05-15  12.33  12.45  12.30  12.34      11.13   67700      12.18
# 2023-05-16  12.35  12.45  12.28  12.34      11.13   74200      12.23
# 2023-05-17  12.30  12.44  12.28  12.33      11.12   75100      12.28
# 2023-05-18  12.33  12.49  12.28  12.37      11.16  115000      12.32
# 2023-05-19  12.41  12.61  12.35  12.43      11.21   94300      12.35
# 2023-05-22  12.42  12.54  12.34  12.35      11.14   57000      12.36
# 2023-05-23  12.35  12.44  12.35  12.36      11.15   73900      12.36
# 2023-05-24  12.40  12.48  12.20  12.41      11.20   85300      12.37
# 2023-05-25  12.41  12.57  12.39  12.42      11.20   76100      12.38
# 2023-05-26  12.46  12.63  12.46  12.48      11.26   78000      12.40
# 2023-05-29  12.46  12.67  12.46  12.59      11.36   98000      12.43
# 2023-05-30  12.59  12.64  12.46  12.50      11.28   74200      12.44
# 2023-05-31  12.48  12.51  12.37  12.40      11.19   69600      12.45
# 2023-06-01  12.39  12.43  12.23  12.37      11.16   89400      12.45
# 2023-06-02  12.42  12.46  12.27  12.27      11.07  116900      12.43
# 2023-06-05  12.32  12.35  12.12  12.22      11.02  123700      12.40
# 2023-06-06  12.22  12.48  12.16  12.44      11.22  118700      12.40
# 2023-06-07  12.43  12.58  12.00  12.49      11.27  105400      12.38
# 2023-06-09  12.50  12.64  12.47  12.60      11.37   79600      12.40
#
#             SMA_Long  EMA_Short  EMA_Long  Recommend  Profit
# Date
# 2023-05-12     11.84      12.16     11.85          0       0
# 2023-05-15     11.85      12.20     11.86          0       0
# 2023-05-16     11.86      12.24     11.87          1       0
# 2023-05-17     11.87      12.26     11.88          0       0
# 2023-05-18     11.88      12.29     11.90          0       0
# 2023-05-19     11.89      12.32     11.91          0       0
# 2023-05-22     11.89      12.33     11.92          0       0
# 2023-05-23     11.90      12.34     11.93          0       0
# 2023-05-24     11.91      12.36     11.94         -1       0
# 2023-05-25     11.91      12.37     11.95          0       0
# 2023-05-26     11.92      12.40     11.97          0       0
# 2023-05-29     11.93      12.45     11.98          0       0
# 2023-05-30     11.94      12.46     12.00          1       0
# 2023-05-31     11.95      12.45     12.01          0       0
# 2023-06-01     11.96      12.43     12.01          0       0
# 2023-06-02     11.96      12.39     12.02         -1       0
# 2023-06-05     11.97      12.35     12.03          0       0
# 2023-06-06     11.97      12.37     12.04          0       0
# 2023-06-07     11.98      12.40     12.05          0       0
# 2023-06-09     11.99      12.45     12.06          0       0

# %%
buy_price = 0 
in_position = False 
num_stocks = 0

for index, row in data.iterrows():
    if row['Recommend'] == 1 and not in_position:
        buy_price = row['Adj Close']
        in_position = True 
        num_stocks = int(initial_amount/buy_price)

    elif row['Recommend'] == -1 and in_position:
        sell_price = row['Adj Close']
        data.at[index, 'Profit'] = (sell_price - buy_price) #* num_stocks
        in_position = False 

data.Profit.sum().round(2)
# Out:
# C:\Users\z004s8rp\AppData\Local\Temp\ipykernel_12328\238883802.py:13: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.06999999999999851' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.at[index, 'Profit'] = (sell_price - buy_price) #* num_stocks
# -0.14

# %%
plt.figure(figsize=(20, 6))
plt.plot(data.index, data['Close'], label='Preço de Fechamento', linewidth=1, color='green')
plt.plot(data.index, data['Close'], label='Preço de Fechamento', linewidth=1, color='green')
plt.plot(data.index, data['SMA_Short'], label=f'SMA {short_window} dias', linewidth=2, color='blue')
plt.plot(data.index, data['SMA_Long'], label=f'SMA {long_window} dias', linewidth=2, color='orange')
str_short = "SMA_Short"
str_long = "SMA_Long"
buy_signals = data[(data[str_short] > data[str_long]) & (data[str_short].shift(1) <= data[str_long].shift(1))]
sell_signals = data[(data[str_short] < data[str_long]) & (data[str_short].shift(1) >= data[str_long].shift(1))]
plt.scatter(buy_signals.index, data.loc[buy_signals.index, str_short], marker='^', color='green', linewidth=12, label='Compra')
plt.scatter(sell_signals.index, data.loc[sell_signals.index, str_short], marker='v', color='red', linewidth=12, label='Venda')


plt.xlabel("Data")
plt.ylabel("Preço de Fechamento")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Defining Functions

# %%
def backtest_sma(ticker, start_date, end_date, short_window, long_window, initial_amount, show_graph):
    yf.pdr_override()
    data = round(web.get_data_yahoo(ticker, start=start_date, end=end_date), 2)

    data['EMA_Short'] = data['Close'].ewm(span=short_window).mean().round(2)
    data['EMA_Long'] = data['Close'].ewm(span=long_window).mean().round(2)
    data.dropna(inplace=True)

    str_short = "EMA_Short"
    str_long = "EMA_Long"

    # Lógica para os buy signals
    buy_signals = (data[str_short] > data[str_long]) & (data[str_short].shift(1) <= data[str_long].shift(1))
    sell_signals = (data[str_short] < data[str_long]) & (data[str_short].shift(1) >= data[str_long].shift(1))

    # Criação da coluna 'Buy_Signal' com 1 para buy signal e 0 caso contrário
    data['Buy_Signal'] = np.where(buy_signals, 1, 0)
    data['Sell_Signal'] = np.where(sell_signals, -1, 0)


    data['Recommend'] = 0
    data.loc[data['Buy_Signal'] == 1, 'Recommend'] = 1
    data.loc[data['Sell_Signal'] == -1, 'Recommend'] = -1
    data = data.drop(['Buy_Signal', 'Sell_Signal'], axis=1)
    data['Profit'] = 0
    buy_price = 0 
    in_position = False 
    num_stocks = 0

    for index, row in data.iterrows():
        if initial_amount> 0:
            if row['Recommend'] == 1 and not in_position:
                buy_price = row['Adj Close']
                in_position = True 
                num_stocks = int(initial_amount/buy_price)

            elif row['Recommend'] == -1 and in_position:
                sell_price = row['Adj Close']
                profit = (int((sell_price - buy_price) * num_stocks)) 
                data.at[index, 'Profit'] = profit

                if profit < 0:
                    initial_amount += profit
                in_position = False
        else:
            print("Lost all amount.")
            break

    print(f"-------------------------------------------------------------------------")
    print(f"Ticker {ticker}")
    print(f"Short Window: {short_window} - Long Window {long_window}")
    print(f"Profit obtained: BRL {data['Profit'].sum()}")
    print(f"Yield of the investment: {round(data['Profit'].sum() * 100 /initial_amount, 2)} %")
    if(show_graph):
        plot_graph(data, str_short, str_long)

# %%
def plot_graph(data, str_short, str_long):
    plt.figure(figsize=(20, 6))
    plt.plot(data.index, data['Close'], label='Preço de Fechamento', linewidth=1, color='green')
    plt.plot(data.index, data['Close'], label='Preço de Fechamento', linewidth=1, color='green')
    plt.plot(data.index, data['EMA_Short'], label=f'SMA {short_window} dias', linewidth=2, color='blue')
    plt.plot(data.index, data['EMA_Long'], label=f'SMA {long_window} dias', linewidth=2, color='orange')
    str_short = "EMA_Short"
    str_long = "EMA_Long"
    buy_signals = data[(data[str_short] > data[str_long]) & (data[str_short].shift(1) <= data[str_long].shift(1))]
    sell_signals = data[(data[str_short] < data[str_long]) & (data[str_short].shift(1) >= data[str_long].shift(1))]
    plt.scatter(buy_signals.index, data.loc[buy_signals.index, str_short], marker='^', color='green', linewidth=5, label='Compra')
    plt.scatter(sell_signals.index, data.loc[sell_signals.index, str_short], marker='v', color='red', linewidth=5, label='Venda')


    plt.xlabel("Data")
    plt.ylabel("Preço de Fechamento")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
start_date = "2023-07-01"
end_date = datetime.today().strftime('%Y-%m-%d')
short_windows = [5, 10]
long_windows = [20, 30, 40]
tickers = [
    "ITSA4.SA"]

for ticker in tickers:
    for short_window in short_windows:
        for long_window in long_windows:            
            backtest_sma(ticker, start_date=start_date, end_date=end_date, short_window=short_window, long_window=long_window, initial_amount=initial_amount, show_graph=True)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# -------------------------------------------------------------------------
# Ticker ITSA4.SA
# Short Window: 5 - Long Window 20
# Profit obtained: BRL 1377
# Yield of the investment: 14.63 %
# [*********************100%%**********************]  1 of 1 completed
# -------------------------------------------------------------------------
# Ticker ITSA4.SA
# Short Window: 5 - Long Window 30
# Profit obtained: BRL 1156
# Yield of the investment: 12.47 %
# [*********************100%%**********************]  1 of 1 completed
# -------------------------------------------------------------------------
# Ticker ITSA4.SA
# Short Window: 5 - Long Window 40
# Profit obtained: BRL 1703
# Yield of the investment: 17.62 %
# [*********************100%%**********************]  1 of 1 completed
# -------------------------------------------------------------------------
# Ticker ITSA4.SA
# Short Window: 10 - Long Window 20
# Profit obtained: BRL 727
# Yield of the investment: 7.76 %
# [*********************100%%**********************]  1 of 1 completed
# -------------------------------------------------------------------------
# Ticker ITSA4.SA
# Short Window: 10 - Long Window 30
# Profit obtained: BRL 1104
# Yield of the investment: 12.08 %
# [*********************100%%**********************]  1 of 1 completed
# -------------------------------------------------------------------------
# Ticker ITSA4.SA
# Short Window: 10 - Long Window 40
# Profit obtained: BRL 1104
# Yield of the investment: 12.08 %
